# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup

# --- Part 1: Initial Setup ---
# Defining the HTML source as a string variable
html_doc = """
<html>
  <body>
    <h1>Product X Customer Reviews</h1>
    <div class="review-container" id="review-1">
      <p class="reviewer-name">-- Jane Doe</p>
      <h2 class="review-title">Solid performance, minor flaw.</h2>
      <p class="review-body">
        I've been using this product for a week now. The speed is unbelievable, 
        but the documentation is very confusing (poorly written). I'm still happy!
      </p>
      <div class="rating">Rating: 4/5</div>
    </div>
    <div class="review-container" id="review-2">
      <p class="reviewer-name">-- John Smith</p>
      <h2 class="review-title">Best purchase of the year!</h2>
      <p class="review-body">
        The quality of the materials is excellent. Definitely recommend it!
        It performs well.
      </p>
      <div class="rating">Rating: 5/5</div>
    </div>
  </body>
</html>
"""

# --- Part 2: Implementation ---

# 1. Initialize BeautifulSoup object
soup = BeautifulSoup(html_doc, 'html.parser')

# 2. Find all review blocks
# We use find_all to get a list of all divs with the class 'review-container'
# INSERT YOUR CODE BELOW

# 3. Loop through each review block
# INSERT YOUR CODE BELOW
    
    # Extract elements using the specific class names
    # INSERT YOUR CODE BELOW
    
    # Extract text and Perform Cleaning
    # INSERT YOUR CODE BELOW
        # Clean Name: Strip whitespace. 
        # Note: To match your expected output "Review from Jane Doe", 
        # we also remove the "-- " characters found in the HTML.
        # INSERT YOUR CODE BELOW
        
        # Clean Title: The expected output shows the title in lowercase
        # INSERT YOUR CODE BELOW
        
        # Clean Body: Convert to lowercase and strip whitespace/newlines
        # We replace newlines with spaces to make it a single clean line
        # INSERT YOUR CODE BELOW
        
        # remove double spaces caused by the newline replacement
        # INSERT YOUR CODE BELOW

        # 4. Print formatted output
print(html_doc)
        # INSERT YOUR CODE BELOW

# %%
# %pip install nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# --- Part 1: Initial Setup & Downloads ---
# We ensure the necessary NLTK data is downloaded. 
# 'quiet=True' hides the download progress bars.
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True) # Required for some newer NLTK versions
nltk.download('stopwords', quiet=True)

# Dataset
SPAM_EMAIL = "URGENT! You have won a FREE lottery prize of $1,000,000! Click here to claim your money now! WIN WIN WIN!"
LEGIT_EMAIL = "I'm sending the documents you requested. They are attached. Let me know if you have any questions."

# --- Part 2: Implementation ---

def preprocess_text(text):
    """
    Applies the NLP pipeline: Lowercase -> Tokenize -> Remove Stop Words -> Stem
    """
    # 1. Case Folding (Lowercase)

    
    # 2. Tokenization
   
    
    # 3. Remove Stop Words
  
    # We filter out words that are in the stop_word list.
  
    
    # 4. Apply Stemming
    ps = PorterStemmer()
    stemmed_tokens = 
    
    return stemmed_tokens

def analyze_email(email_text, label):
    """
    Calculates spam score and classifies the email.
    """
    # Define Spam Trigger Stems
    # Note: 'money' becomes 'mone' after Porter Stemming
    spam_triggers = ['free', 'win', 'mone', 'urgent']
    
    # Run the pipeline

    
    # Count Spam Occurrences
            
    # Calculate Score
    # Avoid division by zero if email is empty

        
    # Classification (Threshold 0.2)
    
    # --- Output Results ---
 

# --- Execution ---
analyze_email(SPAM_EMAIL, "Email A")
analyze_email(LEGIT_EMAIL, "Email B")
